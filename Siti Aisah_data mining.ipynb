# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew,kurtosis

# %%
df= pd.read_csv("C:/Users/Siti aisah/Data Mining/obesity_data.csv")

# %%
df.head()
# Out:
#    Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 0   56    Male  173.575262  71.982051  23.891783                      4
# 1   69    Male  164.127306  89.959256  33.395209                      2
# 2   46  Female  168.072202  72.930629  25.817737                      4
# 3   32    Male  168.459633  84.886912  29.912247                      3
# 4   60    Male  183.568568  69.038945  20.487903                      3
#
#   ObesityCategory
# 0   Normal weight
# 1           Obese
# 2      Overweight
# 3      Overweight
# 4   Normal weight

# %%
df.tail()
# Out:
#      Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 995   18    Male  155.588674  64.103182  26.480345                      4
# 996   35  Female  165.076490  97.639771  35.830783                      1
# 997   49  Female  156.570956  78.804284  32.146036                      1
# 998   64    Male  164.192222  57.978115  21.505965                      4
# 999   66  Female  178.537130  74.962164  23.517168                      1
#
#     ObesityCategory
# 995      Overweight
# 996           Obese
# 997           Obese
# 998   Normal weight
# 999   Normal weight

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    1000 non-null   int64
#  1   Gender                 1000 non-null   object
#  2   Height                 1000 non-null   float64
#  3   Weight                 1000 non-null   float64
#  4   BMI                    1000 non-null   float64
#  5   PhysicalActivityLevel  1000 non-null   int64
#  6   ObesityCategory        1000 non-null   object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 54.8+ KB

# %%
df.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Height                   0
# Weight                   0
# BMI                      0
# PhysicalActivityLevel    0
# ObesityCategory          0
# dtype: int64

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Age', 'Height', 'Weight', 'BMI', 'PhysicalActivityLevel'], dtype='object')

# %%
numeric_df = df.select_dtypes(include=['number'])

numeric_df = df.select_dtypes(include=['number'])
print("---Mean---")
print(numeric_df.mean())
print (" ")
print("---Median---")
print(numeric_df.median())
print (" ")
print("---Mode---")
print(numeric_df.mode().iloc[0])
print (" ")
print("---Std---")
print(numeric_df.std())
print (" ")
print("---Var---")
print(numeric_df.var())
print (" ")
print("---Skew---")
print(numeric_df.skew())
print (" ")
print("---Kurtosis---")
kurtosis_values = df[['Age', 'Height', 'Weight', 'BMI', 'PhysicalActivityLevel']].apply(kurtosis)
print("Kurtosis:")
print(kurtosis_values)
# Out:
# ---Mean---
# Age                       49.857000
# Height                   170.052417
# Weight                    71.205769
# BMI                       24.888317
# PhysicalActivityLevel      2.534000
# dtype: float64
#
# ---Median---
# Age                       50.000000
# Height                   169.801665
# Weight                    71.929072
# BMI                       24.698647
# PhysicalActivityLevel      3.000000
# dtype: float64
#
# ---Mode---
# Age                       79.000000
# Height                   136.115719
# Weight                    26.065730
# BMI                        8.470572
# PhysicalActivityLevel      4.000000
# Name: 0, dtype: float64
#
# ---Std---
# Age                      18.114267
# Height                   10.309971
# Weight                   15.509849
# BMI                       6.193912
# PhysicalActivityLevel     1.116284
# dtype: float64
#
# ---Var---
# Age                      328.126678
# Height                   106.295498
# ...

# %%
df.describe().T
# Out:
#                         count        mean        std         min         25%  \
# Age                    1000.0   49.857000  18.114267   18.000000   35.000000
# Height                 1000.0  170.052417  10.309971  136.115719  163.514205
# Weight                 1000.0   71.205769  15.509849   26.065730   61.129629
# BMI                    1000.0   24.888317   6.193912    8.470572   20.918068
# PhysicalActivityLevel  1000.0    2.534000   1.116284    1.000000    2.000000
#
#                               50%         75%         max
# Age                     50.000000   66.000000   79.000000
# Height                 169.801665  177.353596  201.419670
# Weight                  71.929072   81.133746  118.907366
# BMI                     24.698647   28.732132   50.791898
# PhysicalActivityLevel    3.000000    4.000000    4.000000

# %%
numeric_df = df.select_dtypes(include=['number'])
# Korelasi antar variabel numerik
numeric_df.corr()
# Out:
#                             Age    Height    Weight       BMI  \
# Age                    1.000000  0.019647 -0.061400 -0.059971
# Height                 0.019647  1.000000  0.016033 -0.477091
# Weight                -0.061400  0.016033  1.000000  0.861438
# BMI                   -0.059971 -0.477091  0.861438  1.000000
# PhysicalActivityLevel -0.022308  0.030380  0.063406  0.038020
#
#                        PhysicalActivityLevel
# Age                                -0.022308
# Height                              0.030380
# Weight                              0.063406
# BMI                                 0.038020
# PhysicalActivityLevel               1.000000

# %%
# Histogram
df.hist(figsize=(10, 5))
plt.tight_layout()
plt.show()

# Box Plot
df.plot(kind='box', subplots=True, layout=(len(df.columns)//2, 2), figsize=(10, 5))
plt.tight_layout()
plt.show()

# Scatter plot antara pasangan variabel numerik
sns.pairplot(df)
plt.show()

# %%
# Menghitung matriks korelasi
correlation_matrix = df[['Age', 'Height', 'Weight', 'BMI', 'PhysicalActivityLevel']].corr()

# Tampilkan matriks korelasi
print(correlation_matrix)

# Visualisasi matriks korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Matriks Korelasi')
plt.show()
# Out:
#                             Age    Height    Weight       BMI  \
# Age                    1.000000  0.019647 -0.061400 -0.059971
# Height                 0.019647  1.000000  0.016033 -0.477091
# Weight                -0.061400  0.016033  1.000000  0.861438
# BMI                   -0.059971 -0.477091  0.861438  1.000000
# PhysicalActivityLevel -0.022308  0.030380  0.063406  0.038020
#
#                        PhysicalActivityLevel
# Age                                -0.022308
# Height                              0.030380
# Weight                              0.063406
# BMI                                 0.038020
# PhysicalActivityLevel               1.000000
